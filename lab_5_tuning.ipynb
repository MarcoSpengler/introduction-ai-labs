# %%
import sklearn

import numpy as np
import os   

np.random.seed(42)

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

PROJECT_ROOT_DIR = "."
CHAPTER_ID = "classification"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version=1, as_frame=False)

X, y = mnist["data"], mnist["target"]

y = y.astype(np.uint8)

# X_train, X_test, y_train, y_test = X[:60000], X[60000:], y[:60000], y[60000:]

# %%
# we will now train a Support Vector Machine (SVM) classifier with default hyperparameters
from sklearn.svm import SVC

svm_clf_stock = SVC()
svm_clf_stock.fit(X_train, y_train)

# lets see how it performs on the test set

from sklearn.metrics import accuracy_score

y_pred = svm_clf_stock.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9878

# %%
# lets see which hyperparameters it used
svm_clf.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
# we will not use the entire training set, but only a subset to search for the best hyperparameters
# so we will now create a smaller training set but stratified so that each class is represented equally


from sklearn.model_selection import StratifiedShuffleSplit

# Create stratified splits
split = StratifiedShuffleSplit(n_splits=1, test_size=10000, random_state=42)
for train_index, test_index in split.split(X, y):
    X_train_full = X[train_index]
    y_train_full = y[train_index]
    X_test = X[test_index]
    y_test = y[test_index]

# Further split the training set into a smaller subset for hyperparameter tuning
split = StratifiedShuffleSplit(n_splits=1, test_size=10000, random_state=42)
for train_index, subset_index in split.split(X_train_full, y_train_full):
    X_train_subset = X_train_full[subset_index]
    y_train_subset = y_train_full[subset_index]

# %%
# show size og the subsets
X_train_subset.shape
# Out:
# (10000, 784)

# %%
# lets tune the hyperparameters
from sklearn.model_selection import GridSearchCV

param_grid = [
    {'kernel': ['linear'], 'C': [10., 1000., 3000., 30000.0]},
    {'kernel': ['rbf'], 'gamma': [ 0.1, 0.3, 1.0, 3.0], 'C': [10., 100., 1000., 10000]},
]

grid_search = GridSearchCV(svm_clf, param_grid, cv=3, verbose=3)
grid_search.fit(
    X_train_subset, y_train_subset)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV 1/3] END .............C=10.0, kernel=linear;, score=0.916 total time=   8.5s
# [CV 2/3] END .............C=10.0, kernel=linear;, score=0.908 total time=   8.7s
# [CV 3/3] END .............C=10.0, kernel=linear;, score=0.900 total time=   9.9s
# [CV 1/3] END ...........C=1000.0, kernel=linear;, score=0.916 total time=   8.8s
# [CV 2/3] END ...........C=1000.0, kernel=linear;, score=0.908 total time=   8.4s
# [CV 3/3] END ...........C=1000.0, kernel=linear;, score=0.900 total time=   8.2s
# [CV 1/3] END ...........C=3000.0, kernel=linear;, score=0.916 total time=   8.4s
# [CV 2/3] END ...........C=3000.0, kernel=linear;, score=0.908 total time=   8.4s
# [CV 3/3] END ...........C=3000.0, kernel=linear;, score=0.900 total time=   8.1s
# [CV 1/3] END ..........C=30000.0, kernel=linear;, score=0.916 total time=   8.2s
# [CV 2/3] END ..........C=30000.0, kernel=linear;, score=0.908 total time=   8.4s
# [CV 3/3] END ..........C=30000.0, kernel=linear;, score=0.900 total time=   8.4s
# [CV 1/3] END .....C=10.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 2/3] END .....C=10.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END .....C=10.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END .....C=10.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 2/3] END .....C=10.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END .....C=10.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END .....C=10.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 2/3] END .....C=10.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 3/3] END .....C=10.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.6min
# [CV 1/3] END .....C=10.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.5min
# [CV 2/3] END .....C=10.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.6min
# [CV 3/3] END .....C=10.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.5min
# [CV 1/3] END ....C=100.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 2/3] END ....C=100.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 3/3] END ....C=100.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 1/3] END ....C=100.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.9min
# [CV 2/3] END ....C=100.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.6min
# [CV 3/3] END ....C=100.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.9min
# [CV 1/3] END ....C=100.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 2.3min
# [CV 2/3] END ....C=100.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.5min
# [CV 3/3] END ....C=100.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.6min
# [CV 1/3] END ....C=100.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 2/3] END ....C=100.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END ....C=100.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END ...C=1000.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END ...C=1000.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END ...C=1000.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 1/3] END ...C=1000.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END ...C=1000.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END ...C=1000.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 1/3] END ...C=1000.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.5min
# [CV 2/3] END ...C=1000.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 3/3] END ...C=1000.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 1/3] END ...C=1000.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.5min
# [CV 2/3] END ...C=1000.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.5min
# [CV 3/3] END ...C=1000.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.5min
# [CV 1/3] END ....C=10000, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 2/3] END ....C=10000, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 3/3] END ....C=10000, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END ....C=10000, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.5min
# [CV 2/3] END ....C=10000, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 3/3] END ....C=10000, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.6min
# [CV 1/3] END ....C=10000, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.7min
# [CV 2/3] END ....C=10000, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 3/3] END ....C=10000, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END ....C=10000, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 2/3] END ....C=10000, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 3/3] END ....C=10000, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.2min
# GridSearchCV(cv=3, estimator=SVC(),
#              param_grid=[{'C': [10.0, 1000.0, 3000.0, 30000.0],
#                           'kernel': ['linear']},
#                          {'C': [10.0, 100.0, 1000.0, 10000],
#                           'gamma': [0.1, 0.3, 1.0, 3.0], 'kernel': ['rbf']}],
#              verbose=3)

# %%
# lets see the best hyperparameters
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'C': 10.0, 'kernel': 'linear'}
# 0.9077333333333333

# %%
# lets try random search
from sklearn.model_selection import RandomizedSearchCV

from scipy.stats import expon, reciprocal

param_distribs = {
    'kernel': ['linear', 'rbf'],
    'C': reciprocal(20, 200000),
    'gamma': expon(scale=1.0),
}

svm_clf = SVC()
rnd_search = RandomizedSearchCV(svm_clf, param_distribs, n_iter=50, cv=3, verbose=3)
rnd_search.fit(X_train_subset, y_train_subset)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV 1/3] END C=280.0238382822748, gamma=0.8936325301461753, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END C=280.0238382822748, gamma=0.8936325301461753, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END C=280.0238382822748, gamma=0.8936325301461753, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END C=200.46355957145818, gamma=0.03960891229942073, kernel=linear;, score=0.916 total time=   8.3s
# [CV 2/3] END C=200.46355957145818, gamma=0.03960891229942073, kernel=linear;, score=0.908 total time=   8.0s
# [CV 3/3] END C=200.46355957145818, gamma=0.03960891229942073, kernel=linear;, score=0.900 total time=   8.1s
# [CV 1/3] END C=551.8138050879572, gamma=0.135889041297428, kernel=linear;, score=0.916 total time=   8.3s
# [CV 2/3] END C=551.8138050879572, gamma=0.135889041297428, kernel=linear;, score=0.908 total time=   7.8s
# [CV 3/3] END C=551.8138050879572, gamma=0.135889041297428, kernel=linear;, score=0.900 total time=   7.9s
# [CV 1/3] END C=40973.77807137847, gamma=0.3168265649239175, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 2/3] END C=40973.77807137847, gamma=0.3168265649239175, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END C=40973.77807137847, gamma=0.3168265649239175, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END C=6202.8588544254835, gamma=0.08921102898989729, kernel=linear;, score=0.916 total time=   7.9s
# [CV 2/3] END C=6202.8588544254835, gamma=0.08921102898989729, kernel=linear;, score=0.908 total time=   8.0s
# [CV 3/3] END C=6202.8588544254835, gamma=0.08921102898989729, kernel=linear;, score=0.900 total time=   7.6s
# [CV 1/3] END C=119.82574329084515, gamma=0.5299301333993761, kernel=linear;, score=0.916 total time=   8.0s
# [CV 2/3] END C=119.82574329084515, gamma=0.5299301333993761, kernel=linear;, score=0.908 total time=   7.6s
# [CV 3/3] END C
kernel=linear;, score=0.908 total time=   7.6s
# [CV 3/3] END C=3535.8738664713214, gamma=0.2725923107847457, kernel=linear;, score=0.900 total time=   7.5s
# [CV 1/3] END C=20161.101999861243, gamma=1.4046329868550171, kernel=linear;, score=0.916 total time=   7.8s
# [CV 2/3] END C=20161.101999861243, gamma=1.4046329868550171, kernel=linear;, score=0.908 total time=   7.6s
# [CV 3/3] END C=20161.101999861243, gamma=1.4046329868550171, kernel=linear;, score=0.900 total time=   7.4s
# [CV 1/3] END C=648.5531012298183, gamma=0.7642726247871977, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 2/3] END C=648.5531012298183, gamma=0.7642726247871977, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 3/3] END C=648.5531012298183, gamma=0.7642726247871977, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END C=40444.53625685926, gamma=0.3857354261645083, kernel=linear;, score=0.916 total time=   7.6s
# [CV 2/3] END C=40444.53625685926, gamma=0.3857354261645083, kernel=linear;, score=0.908 total time=   7.5s
# [CV 3/3] END C=40444.53625685926, gamma=0.3857354261645083, kernel=linear;, score=0.900 total time=   7.4s
# [CV 1/3] END C=50.23073630719763, gamma=0.05496877411360514, kernel=linear;, score=0.916 total time=   7.6s
# [CV 2/3] END C=50.23073630719763, gamma=0.05496877411360514, kernel=linear;, score=0.908 total time=   7.5s
# [CV 3/3] END C=50.23073630719763, gamma=0.05496877411360514, kernel=linear;, score=0.900 total time=   7.5s
# [CV 1/3] END C=83667.71364292072, gamma=0.09572561054847525, kernel=linear;, score=0.916 total time=   7.8s
# [CV 2/3] END C=83667.71364292072, gamma=0.09572561054847525, kernel=linear;, score=0.908 total time=   7.6s
# [CV 3/3] END C=83667.71364292072, gamma=0.09572561054847525, kernel=linear;, score=0.900 total time=   7.4s
# [CV 1/3] END C=134348.72095823046, gamma=1.1293908391713003, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 2/3] END C=134348.72095823046, gamma=1.1293908391713003, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 3/3] END C=134348.72095823046, gamma=1.1293908391713003, kernel=rbf;, score=0.113 total time= 1.2min
# RandomizedSearchCV(cv=3, estimator=SVC(), n_iter=50,
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x31f30a0c0>,
#                                         'gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x31f3089b0>,
#                                         'kernel': ['linear', 'rbf']},
#                    verbose=3)

# %%
# lets see the best hyperparameters and score
print(rnd_search.best_params_)
print(rnd_search.best_score_)
# Out:
# {'C': 200.46355957145818, 'gamma': 0.03960891229942073, 'kernel': 'linear'}
# 0.9077333333333333

# %%
# now we will run the best model on the entire training set
from sklearn.metrics import accuracy_score

y_pred = grid_search.best_estimator_.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9157

# %%
# lets try a grid search again this time optimizing 
# degree, C and coef0 for the polynomial kernel
# and C and gamma for the RBF kernel

param_grid = [
    {'kernel': ['poly'], 'degree': [3, 4, 5], 'C': [10., 100., 1000., 10000.0]},
    {'kernel': ['rbf'], 'gamma': [ 0.1, 0.3, 1.0, 3.0], 'C': [10., 100., 1000., 10000]},
]

grid_search = GridSearchCV(svm_clf, param_grid, cv=3, verbose=3)
grid_search.fit(
    X_train_subset, y_train_subset)
# Out:
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
#
END .....C=10.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END .....C=10.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END .....C=10.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END .....C=10.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END .....C=10.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END .....C=10.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END .....C=10.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END .....C=10.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END .....C=10.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END .....C=10.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END .....C=10.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END .....C=10.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END ....C=100.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END ....C=100.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END ....C=100.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 1/3] END ....C=100.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END ....C=100.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END ....C=100.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END ....C=100.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END ....C=100.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END ....C=100.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END ....C=100.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END ....C=100.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END ....C=100.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 1/3] END ...C=1000.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END ...C=1000.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 3/3] END ...C=1000.0, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 1/3] END ...C=1000.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 2/3] END ...C=1000.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 3/3] END ...C=1000.0, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.4min
# [CV 1/3] END ...C=1000.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END ...C=1000.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END ...C=1000.0, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END ...C=1000.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END ...C=1000.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END ...C=1000.0, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END ....C=10000, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END ....C=10000, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 3/3] END ....C=10000, gamma=0.1, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 1/3] END ....C=10000, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 2/3] END ....C=10000, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END ....C=10000, gamma=0.3, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END ....C=10000, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END ....C=10000, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 3/3] END ....C=10000, gamma=1.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END ....C=10000, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 2/3] END ....C=10000, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END ....C=10000, gamma=3.0, kernel=rbf;, score=0.113 total time= 1.2min
# GridSearchCV(cv=3, estimator=SVC(),
#              param_grid=[{'C': [10.0, 100.0, 1000.0, 10000.0],
#                           'degree': [3, 4, 5], 'kernel': ['poly']},
#                          {'C': [10.0, 100.0, 1000.0, 10000],
#                           'gamma': [0.1, 0.3, 1.0, 3.0], 'kernel': ['rbf']}],
#              verbose=3)

# %%
# lets see the best hyperparameters and score
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'C': 10.0, 'degree': 3, 'kernel': 'poly'}
# 0.9574666666666666

# %%
# now random search
param_distribs = {
    'kernel': ['poly', 'rbf'],
    'C': reciprocal(20, 200000),
    'gamma': expon(scale=1.0),
    'degree': [3, 4, 5],
    'coef0': [0, 1, 2],
}

svm_clf = SVC()
rnd_search = RandomizedSearchCV(svm_clf, param_distribs, n_iter=50, cv=3, verbose=3)
rnd_search.fit(X_train_subset, y_train_subset)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV 1/3] END C=199480.61055720522, coef0=1, degree=5, gamma=0.810651592641394, kernel=poly;, score=0.934 total time=  10.0s
# [CV 2/3] END C=199480.61055720522, coef0=1, degree=5, gamma=0.810651592641394, kernel=poly;, score=0.922 total time=   9.8s
# [CV 3/3] END C=199480.61055720522, coef0=1, degree=5, gamma=0.810651592641394, kernel=poly;, score=0.926 total time=   9.8s
# [CV 1/3] END C=16051.416797380823, coef0=1, degree=4, gamma=0.47457494062801897, kernel=poly;, score=0.950 total time=   9.0s
# [CV 2/3] END C=16051.416797380823, coef0=1, degree=4, gamma=0.47457494062801897, kernel=poly;, score=0.939 total time=   9.1s
# [CV 3/3] END C=16051.416797380823, coef0=1, degree=4, gamma=0.47457494062801897, kernel=poly;, score=0.944 total time=   9.2s
# [CV 1/3] END C=1268.2548649032617, coef0=1, degree=3, gamma=3.080223786441709, kernel=poly;, score=0.964 total time=   8.7s
# [CV 2/3] END C=1268.2548649032617, coef0=1, degree=3, gamma=3.080223786441709, kernel=poly;, score=0.950 total time=   8.6s
# [CV 3/3] END C=1268.2548649032617, coef0=1, degree=3, gamma=3.080223786441709, kernel=poly;, score=0.956 total time=   8.5s
# [CV 1/3] END C=134.87783669713346, coef0=0, degree=3, gamma=1.4146902643402648, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 2/3] END C=134.87783669713346, coef0=0, degree=3, gamma=1.4146902643402648, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 3/3] END C=134.87783669713346, coef0=0, degree=3, gamma=1.4146902643402648, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 1/3] END C
kernel=rbf;, score=0.113 total time= 1.2min
# [CV 3/3] END C=186.4957440239463, coef0=2, degree=3, gamma=0.9431996574293565, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 1/3] END C=44.68797897443541, coef0=1, degree=5, gamma=2.6884585115949906, kernel=poly;, score=0.934 total time=   9.9s
# [CV 2/3] END C=44.68797897443541, coef0=1, degree=5, gamma=2.6884585115949906, kernel=poly;, score=0.922 total time=   9.8s
# [CV 3/3] END C=44.68797897443541, coef0=1, degree=5, gamma=2.6884585115949906, kernel=poly;, score=0.926 total time=   9.9s
# [CV 1/3] END C=2700.1489735838754, coef0=0, degree=4, gamma=0.41038360138042324, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 2/3] END C=2700.1489735838754, coef0=0, degree=4, gamma=0.41038360138042324, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END C=2700.1489735838754, coef0=0, degree=4, gamma=0.41038360138042324, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 1/3] END C=3129.265898769674, coef0=1, degree=4, gamma=0.38913002251942025, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 2/3] END C=3129.265898769674, coef0=1, degree=4, gamma=0.38913002251942025, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 3/3] END C=3129.265898769674, coef0=1, degree=4, gamma=0.38913002251942025, kernel=rbf;, score=0.113 total time= 1.3min
# [CV 1/3] END C=44.92648494278129, coef0=2, degree=3, gamma=0.0027145805564561002, kernel=poly;, score=0.964 total time=   9.1s
# [CV 2/3] END C=44.92648494278129, coef0=2, degree=3, gamma=0.0027145805564561002, kernel=poly;, score=0.950 total time=   8.9s
# [CV 3/3] END C=44.92648494278129, coef0=2, degree=3, gamma=0.0027145805564561002, kernel=poly;, score=0.956 total time=   8.7s
# [CV 1/3] END C=4825.973780907849, coef0=1, degree=5, gamma=1.5812851951914833, kernel=poly;, score=0.934 total time=  10.3s
# [CV 2/3] END C=4825.973780907849, coef0=1, degree=5, gamma=1.5812851951914833, kernel=poly;, score=0.922 total time=  10.0s
# [CV 3/3] END C=4825.973780907849, coef0=1, degree=5, gamma=1.5812851951914833, kernel=poly;, score=0.926 total time=  10.1s
# [CV 1/3] END C=104507.28676328696, coef0=1, degree=4, gamma=0.13272854183610555, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 2/3] END C=104507.28676328696, coef0=1, degree=4, gamma=0.13272854183610555, kernel=rbf;, score=0.113 total time= 1.2min
# [CV 3/3] END C=104507.28676328696, coef0=1, degree=4, gamma=0.13272854183610555, kernel=rbf;, score=0.113 total time= 1.2min
# RandomizedSearchCV(cv=3, estimator=SVC(), n_iter=50,
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x31f30bc50>,
#                                         'coef0': [0, 1, 2], 'degree': [3, 4, 5],
#                                         'gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x31f30ac60>,
#                                         'kernel': ['poly', 'rbf']},
#                    verbose=3)

# %%
# lets see the params and score
print(rnd_search.best_params_)
print(rnd_search.best_score_)
# Out:
# {'C': 1268.2548649032617, 'coef0': 1, 'degree': 3, 'gamma': 3.080223786441709, 'kernel': 'poly'}
# 0.9564

# %%
# the grid search seems to have found the best hyperparameters
# lets run it on the whole training set

y_pred = grid_search.best_estimator_.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9641

# %%
# so poly seems to perform the best in our searches
# lets try to tune the hyperparameters even more

param_grid = [
    {'kernel': ['poly'], 'degree': [ 5], 'C': [1, 2,3,10.,], 'coef0': [0, 1, 2]},
]

grid_search2 = GridSearchCV(svm_clf, param_grid, cv=3, verbose=3)
grid_search2.fit(X_train_subset, y_train_subset)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV 1/3] END C=1, coef0=0, degree=5, kernel=poly;, score=0.872 total time=   8.5s
# [CV 2/3] END C=1, coef0=0, degree=5, kernel=poly;, score=0.888 total time=   8.9s
# [CV 3/3] END C=1, coef0=0, degree=5, kernel=poly;, score=0.875 total time=   8.8s
# [CV 1/3] END C=1, coef0=1, degree=5, kernel=poly;, score=0.954 total time=   5.7s
# [CV 2/3] END C=1, coef0=1, degree=5, kernel=poly;, score=0.959 total time=   4.9s
# [CV 3/3] END C=1, coef0=1, degree=5, kernel=poly;, score=0.953 total time=   4.6s
# [CV 1/3] END C=1, coef0=2, degree=5, kernel=poly;, score=0.954 total time=   4.6s
# [CV 2/3] END C=1, coef0=2, degree=5, kernel=poly;, score=0.960 total time=   4.7s
# [CV 3/3] END C=1, coef0=2, degree=5, kernel=poly;, score=0.953 total time=   4.6s
# [CV 1/3] END C=2, coef0=0, degree=5, kernel=poly;, score=0.889 total time=   7.3s
# [CV 2/3] END C=2, coef0=0, degree=5, kernel=poly;, score=0.906 total time=   7.4s
# [CV 3/3] END C=2, coef0=0, degree=5, kernel=poly;, score=0.894 total time=   7.3s
# [CV 1/3] END C=2, coef0=1, degree=5, kernel=poly;, score=0.954 total time=   4.8s
# [CV 2/3] END C=2, coef0=1, degree=5, kernel=poly;, score=0.959 total time=   4.8s
# [CV 3/3] END C=2, coef0=1, degree=5, kernel=poly;, score=0.953 total time=   4.6s
# [CV 1/3] END C=2, coef0=2, degree=5, kernel=poly;, score=0.954 total time=   4.8s
# [CV 2/3] END C=2, coef0=2, degree=5, kernel=poly;, score=0.960 total time=   4.8s
# [CV 3/3] END C=2, coef0=2, degree=5, kernel=poly;, score=0.953 total time=   4.5s
# [CV 1/3] END C=3, coef0=0, degree=5, kernel=poly;, score=0.898 total time=   6.8s
# [CV 2/3] END C=3, coef0=0, degree=5, kernel=poly;, score=0.913 total time=   6.7s
# [CV 3/3] END C=3, coef0=0, degree=5, kernel=poly;, score=0.899 total time=   6.8s
# [CV 1/3] END C=3, coef0=1, degree=5, kernel=poly;, score=0.954 total time=   4.8s
# [CV 2/3] END C=3, coef0=1, degree=5, kernel=poly;, score=0.959 total time=   4.7s
# [CV 3/3] END C=3, coef0=1, degree=5, kernel=poly;, score=0.953 total time=   4.6s
# [CV 1/3] END C=3, coef0=2, degree=5, kernel=poly;, score=0.954 total time=   4.7s
# [CV 2/3] END C=3, coef0=2, degree=5, kernel=poly;, score=0.960 total time=   4.8s
# [CV 3/3] END C=3, coef0=2, degree=5, kernel=poly;, score=0.953 total time=   4.5s
# [CV 1/3] END C=10.0, coef0=0, degree=5, kernel=poly;, score=0.907 total time=   5.9s
# [CV 2/3] END C=10.0, coef0=0, degree=5, kernel=poly;, score=0.923 total time=   5.9s
# [CV 3/3] END C=10.0, coef0=0, degree=5, kernel=poly;, score=0.912 total time=   5.8s
# [CV 1/3] END C=10.0, coef0=1, degree=5, kernel=poly;, score=0.954 total time=   4.8s
# [CV 2/3] END C=10.0, coef0=1, degree=5, kernel=poly;, score=0.959 total time=   4.8s
# [CV 3/3] END C=10.0, coef0=1, degree=5, kernel=poly;, score=0.953 total time=   4.6s
# [CV 1/3] END C=10.0, coef0=2, degree=5, kernel=poly;, score=0.954 total time=   4.5s
# [CV 2/3] END C=10.0, coef0=2, degree=5, kernel=poly;, score=0.960 total time=   4.7s
# [CV 3/3] END C=10.0, coef0=2, degree=5, kernel=poly;, score=0.953 total time=   4.7s
# GridSearchCV(cv=3, estimator=SVC(),
#              param_grid=[{'C': [1, 2, 3, 10.0], 'coef0': [0, 1, 2],
#                           'degree': [5], 'kernel': ['poly']}],
#              verbose=3)

# %%
# lets see the best hyperparameters and score
print(grid_search2.best_params_)
print(grid_search2.best_score_)
# Out:
# {'C': 1, 'coef0': 2, 'degree': 5, 'kernel': 'poly'}
# 0.9556001490970933

# %%
# not looking so good, lets try rbf again with values for c and gamma

param_grid = [
    {'kernel': ['rbf'], 'gamma': [0.1, 1.0, 3.0, "scale"], 'C': [100, 1000]},
]

grid_search = GridSearchCV(svm_clf, param_grid, cv=3, verbose=3)
grid_search.fit(
    X_train_subset, y_train_subset)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV 1/3] END ......C=100, gamma=0.1, kernel=rbf;, score=0.112 total time=  34.9s
# [CV 2/3] END ......C=100, gamma=0.1, kernel=rbf;, score=0.113 total time=  43.3s
# [CV 3/3] END ......C=100, gamma=0.1, kernel=rbf;, score=0.113 total time=  40.1s
# [CV 1/3] END ......C=100, gamma=1.0, kernel=rbf;, score=0.112 total time=  39.2s
# [CV 2/3] END ......C=100, gamma=1.0, kernel=rbf;, score=0.113 total time=  39.4s
# [CV 3/3] END ......C=100, gamma=1.0, kernel=rbf;, score=0.113 total time=  40.2s
# [CV 1/3] END ......C=100, gamma=3.0, kernel=rbf;, score=0.112 total time=  34.9s
# [CV 2/3] END ......C=100, gamma=3.0, kernel=rbf;, score=0.113 total time=  34.9s
# [CV 3/3] END ......C=100, gamma=3.0, kernel=rbf;, score=0.113 total time=  36.2s
# [CV 1/3] END ....C=100, gamma=scale, kernel=rbf;, score=0.964 total time=   8.2s
# [CV 2/3] END ....C=100, gamma=scale, kernel=rbf;, score=0.965 total time=   8.8s
# [CV 3/3] END ....C=100, gamma=scale, kernel=rbf;, score=0.963 total time=  10.4s
# [CV 1/3] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.112 total time=  38.5s
# [CV 2/3] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.113 total time=  36.3s
# [CV 3/3] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.113 total time=  36.6s
# [CV 1/3] END .....C=1000, gamma=1.0, kernel=rbf;, score=0.112 total time=  38.8s
# [CV 2/3] END .....C=1000, gamma=1.0, kernel=rbf;, score=0.113 total time=  38.4s
# [CV 3/3] END .....C=1000, gamma=1.0, kernel=rbf;, score=0.113 total time=  39.9s
# [CV 1/3] END .....C=1000, gamma=3.0, kernel=rbf;, score=0.112 total time=  41.6s
# [CV 2/3] END .....C=1000, gamma=3.0, kernel=rbf;, score=0.113 total time=  38.3s
# [CV 3/3] END .....C=1000, gamma=3.0, kernel=rbf;, score=0.113 total time=  38.7s
# [CV 1/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.964 total time=   8.9s
# [CV 2/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.965 total time=   8.3s
# [CV 3/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.963 total time=   8.1s
# GridSearchCV(cv=3, estimator=SVC(),
#              param_grid=[{'C': [100, 1000], 'gamma': [0.1, 1.0, 3.0, 'scale'],
#                           'kernel': ['rbf']}],
#              verbose=3)

# %%
# lets see the best hyperparameters and score
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.9642999992860714

# %%
# still not looking so good, lets try rbf again with values for c and gamma set to scale

param_grid = [
    {'kernel': ['rbf'], 'gamma': ["scale"], 'C': [1, 5, 10, 50, 100, 1000, 1000, 10000]},
]

grid_search = GridSearchCV(svm_clf, param_grid, cv=3, verbose=3)
grid_search.fit(
    X_train_subset, y_train_subset)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV 1/3] END ......C=1, gamma=scale, kernel=rbf;, score=0.957 total time=   9.2s
# [CV 2/3] END ......C=1, gamma=scale, kernel=rbf;, score=0.958 total time=   8.9s
# [CV 3/3] END ......C=1, gamma=scale, kernel=rbf;, score=0.962 total time=   8.4s
# [CV 1/3] END ......C=5, gamma=scale, kernel=rbf;, score=0.964 total time=   8.2s
# [CV 2/3] END ......C=5, gamma=scale, kernel=rbf;, score=0.965 total time=   8.6s
# [CV 3/3] END ......C=5, gamma=scale, kernel=rbf;, score=0.963 total time=   8.2s
# [CV 1/3] END .....C=10, gamma=scale, kernel=rbf;, score=0.964 total time=   8.3s
# [CV 2/3] END .....C=10, gamma=scale, kernel=rbf;, score=0.965 total time=   8.3s
# [CV 3/3] END .....C=10, gamma=scale, kernel=rbf;, score=0.963 total time=   8.1s
# [CV 1/3] END .....C=50, gamma=scale, kernel=rbf;, score=0.964 total time=   8.2s
# [CV 2/3] END .....C=50, gamma=scale, kernel=rbf;, score=0.965 total time=   8.2s
# [CV 3/3] END .....C=50, gamma=scale, kernel=rbf;, score=0.963 total time=   7.9s
# [CV 1/3] END ....C=100, gamma=scale, kernel=rbf;, score=0.964 total time=   8.0s
# [CV 2/3] END ....C=100, gamma=scale, kernel=rbf;, score=0.965 total time=   8.4s
# [CV 3/3] END ....C=100, gamma=scale, kernel=rbf;, score=0.963 total time=   8.0s
# [CV 1/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.964 total time=   7.9s
# [CV 2/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.965 total time=   8.2s
# [CV 3/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.963 total time=   8.2s
# [CV 1/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.964 total time=   8.2s
# [CV 2/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.965 total time=   8.4s
# [CV 3/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.963 total time=   8.2s
# [CV 1/3] END ..C=10000, gamma=scale, kernel=rbf;, score=0.964 total time=   8.4s
# [CV 2/3] END ..C=10000, gamma=scale, kernel=rbf;, score=0.965 total time=   8.7s
# [CV 3/3] END ..C=10000, gamma=scale, kernel=rbf;, score=0.963 total time=   8.7s
# GridSearchCV(cv=3, estimator=SVC(),
#              param_grid=[{'C': [1, 5, 10, 50, 100, 1000, 1000, 10000],
#                           'gamma': ['scale'], 'kernel': ['rbf']}],
#              verbose=3)

# %%
# lets see the best hyperparameters and score
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.9642999992860714

# %%
# lets tain on the whole training set
y_pred = grid_search.best_estimator_.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9676

# %%
# the accuracy is still not that good lets use gamma scale and different values for C

param_grid = [
    {'kernel': ['rbf'], 'gamma': ["scale"], 'C': [0.2, 0.5 ,1, 5, 10, 50, 100, 1000, 1000, 10000]},
]

grid_search_scale = GridSearchCV(svm_clf, param_grid, cv=3, verbose=3)
grid_search_scale.fit(
    X_train_subset, y_train_subset)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END ....C=0.2, gamma=scale, kernel=rbf;, score=0.935 total time=  12.6s
# [CV 2/3] END ....C=0.2, gamma=scale, kernel=rbf;, score=0.939 total time=  12.1s
# [CV 3/3] END ....C=0.2, gamma=scale, kernel=rbf;, score=0.938 total time=  12.6s
# [CV 1/3] END ....C=0.5, gamma=scale, kernel=rbf;, score=0.948 total time=   9.6s
# [CV 2/3] END ....C=0.5, gamma=scale, kernel=rbf;, score=0.950 total time=   9.8s
# [CV 3/3] END ....C=0.5, gamma=scale, kernel=rbf;, score=0.953 total time=   9.9s
# [CV 1/3] END ......C=1, gamma=scale, kernel=rbf;, score=0.957 total time=   8.4s
# [CV 2/3] END ......C=1, gamma=scale, kernel=rbf;, score=0.958 total time=   8.6s
# [CV 3/3] END ......C=1, gamma=scale, kernel=rbf;, score=0.962 total time=   8.2s
# [CV 1/3] END ......C=5, gamma=scale, kernel=rbf;, score=0.964 total time=   8.2s
# [CV 2/3] END ......C=5, gamma=scale, kernel=rbf;, score=0.965 total time=   8.3s
# [CV 3/3] END ......C=5, gamma=scale, kernel=rbf;, score=0.963 total time=   8.1s
# [CV 1/3] END .....C=10, gamma=scale, kernel=rbf;, score=0.964 total time=   8.3s
# [CV 2/3] END .....C=10, gamma=scale, kernel=rbf;, score=0.965 total time=   9.0s
# [CV 3/3] END .....C=10, gamma=scale, kernel=rbf;, score=0.963 total time=   7.9s
# [CV 1/3] END .....C=50, gamma=scale, kernel=rbf;, score=0.964 total time=   8.0s
# [CV 2/3] END .....C=50, gamma=scale, kernel=rbf;, score=0.965 total time=   8.5s
# [CV 3/3] END .....C=50, gamma=scale, kernel=rbf;, score=0.963 total time=   9.4s
# [CV 1/3] END ....C=100, gamma=scale, kernel=rbf;, score=0.964 total time=   8.1s
# [CV 2/3] END ....C=100, gamma=scale, kernel=rbf;, score=0.965 total time=   8.2s
# [CV 3/3] END ....C=100, gamma=scale, kernel=rbf;, score=0.963 total time=   8.0s
# [CV 1/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.964 total time=   7.9s
# [CV 2/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.965 total time=   8.0s
# [CV 3/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.963 total time=   7.9s
# [CV 1/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.964 total time=   7.9s
# [CV 2/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.965 total time=   8.2s
# [CV 3/3] END ...C=1000, gamma=scale, kernel=rbf;, score=0.963 total time=   8.0s
# [CV 1/3] END ..C=10000, gamma=scale, kernel=rbf;, score=0.964 total time=   8.0s
# [CV 2/3] END ..C=10000, gamma=scale, kernel=rbf;, score=0.965 total time=   8.1s
# [CV 3/3] END ..C=10000, gamma=scale, kernel=rbf;, score=0.963 total time=   7.8s
# GridSearchCV(cv=3, estimator=SVC(),
#              param_grid=[{'C': [0.2, 0.5, 1, 5, 10, 50, 100, 1000, 1000, 10000],
#                           'gamma': ['scale'], 'kernel': ['rbf']}],
#              verbose=3)

# %%
# lets see the best hyperparameters and score
print(grid_search_scale.best_params_)
print(grid_search_scale.best_score_)
# Out:
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.9642999992860714

# %%
# lets try the poly kernel with different values for degree and coef0

param_grid = [
    {'kernel': ['poly'], 'degree': [ 3, 5], 'C': [1, 2,3,10.,], 'coef0': [0, 1, 2]},
]

grid_search_poly = GridSearchCV(svm_clf, param_grid, cv=3, verbose=3)
grid_search_poly.fit(X_train_subset, y_train_subset)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [CV 1/3] END C=1, coef0=0, degree=3, kernel=poly;, score=0.941 total time=   6.0s
# [CV 2/3] END C=1, coef0=0, degree=3, kernel=poly;, score=0.949 total time=   5.9s
# [CV 3/3] END C=1, coef0=0, degree=3, kernel=poly;, score=0.944 total time=   6.4s
# [CV 1/3] END C=1, coef0=0, degree=5, kernel=poly;, score=0.872 total time=   8.8s
# [CV 2/3] END C=1, coef0=0, degree=5, kernel=poly;, score=0.888 total time=   8.2s
# [CV 3/3] END C=1, coef0=0, degree=5, kernel=poly;, score=0.875 total time=   8.4s
# [CV 1/3] END C=1, coef0=1, degree=3, kernel=poly;, score=0.952 total time=   4.4s
# [CV 2/3] END C=1, coef0=1, degree=3, kernel=poly;, score=0.960 total time=   4.4s
# [CV 3/3] END C=1, coef0=1, degree=3, kernel=poly;, score=0.953 total time=   4.3s
# [CV 1/3] END C=1, coef0=1, degree=5, kernel=poly;, score=0.954 total time=   4.6s
# [CV 2/3] END C=1, coef0=1, degree=5, kernel=poly;, score=0.959 total time=   4.7s
# [CV 3/3] END C=1, coef0=1, degree=5, kernel=poly;, score=0.953 total time=   4.5s
# [CV 1/3] END C=1, coef0=2, degree=3, kernel=poly;, score=0.951 total time=   4.2s
# [CV 2/3] END C=1, coef0=2, degree=3, kernel=poly;, score=0.956 total time=   4.5s
# [CV 3/3] END C=1, coef0=2, degree=3, kernel=poly;, score=0.951 total time=   4.5s
# [CV 1/3] END C=1, coef0=2, degree=5, kernel=poly;, score=0.954 total time=   4.5s
# [CV 2/3] END C=1, coef0=2, degree=5, kernel=poly;, score=0.960 total time=   4.7s
# [CV 3/3] END C=1, coef0=2, degree=5, kernel=poly;, score=0.953 total time=   4.6s
# [CV 1/3] END C=2, coef0=0, degree=3, kernel=poly;, score=0.945 total time=   5.4s
# [CV 2/3] END C=2, coef0=0, degree=3, kernel=poly;, score=0.956 total time=   5.4s
# [CV 3/3] END C=2, coef0=0, degree=3, kernel=poly;, score=0.951 total time=   5.1s
# [CV 1/3] END C=2, coef0=0, degree=5, kernel=poly;, score=0.889 total time=   7.1s
# [CV 2/3] END C=2, coef0=0, degree=5, kernel=poly;, score=0.906 total time=   7.4s
# [CV 3/3] END C=2, coef0=0, degree=5, kernel=poly;, score=0.894 total time=   7.8s
# [CV 1/3] END C=2, coef0=1, degree=3, kernel=poly;, score=0.954 total time=   4.7s
# [CV 2/3] END C=2, coef0=1, degree=3, kernel=poly;, score=0.960 total time=   5.2s
# [CV 3/3] END C=2, coef0=1, degree=3, kernel=poly;, score=0.953 total time=   4.6s
# [CV 1/3] END C=2, coef0=1, degree=5, kernel=poly;, score=0.954 total time=   4.7s
# [CV 2/3] END C=2, coef0=1, degree=5, kernel=poly;, score=0.959 total time=   4.9s
# [CV 3/3] END C=2, coef0=1, degree=5, kernel=poly;, score=0.953 total time=   4.7s
# [CV 1/3] END C=2, coef0=2, degree=3, kernel=poly;, score=0.950 total time=   4.2s
# [CV 2/3] END C=2, coef0=2, degree=3, kernel=poly;, score=0.957 total time=   4.4s
# [CV 3/3] END C=2, coef0=2, degree=3, kernel=poly;, score=0.951 total time=   4.4s
# [CV 1/3] END C=2, coef0=2, degree=5, kernel=poly;, score=0.954 total time=   4.8s
# [CV 2/3] END C=2, coef0=2, degree=5, kernel=poly;, score=0.960 total time=   4.7s
# [CV 3/3] END C=2, coef0=2, degree=5, kernel=poly;, score=0.953 total time=   4.6s
# [CV 1/3] END C=3, coef0=0, degree=3, kernel=poly;, score=0.948 total time=   4.9s
# [CV 2/3] END C=3, coef0=0, degree=3, kernel=poly;, score=0.956 total time=   5.1s
# [CV 3/3] END C=3, coef0=0, degree=3, kernel=poly;, score=0.953 total time=   4.9s
# [CV 1/3] END C=3, coef0=0, degree=5, kernel=poly;, score=0.898 total time=   6.7s
# [CV 2/3] END C=3, coef0=0, degree=5, kernel=poly;, score=0.913 total time=   6.9s
# [CV 3/3] END C=3, coef0=0, degree=5, kernel=poly;, score=0.899 total time=   6.9s
# [CV 1/3] END C=3, coef0=1, degree=3, kernel=poly;, score=0.953 total time=   4.4s
# [CV 2/3] END C=3, coef0=1, degree=3, kernel=poly;, score=0.960 total time=   4.5s
# [CV 3/3] END C=3, coef0=1, degree=3, kernel=poly;, score=0.953 total time=   4.4s
# [CV 1/3] END C=3, coef0=1, degree=5, kernel=poly;, score=0.954 total time=   4.6s
# [CV 2/3] END C=3, coef0=1, degree=5, kernel=poly;, score=0.959 total time=   4.8s
# [CV 3/3] END C=3, coef0=1, degree=5, kernel=poly;, score=0.953 total time=   4.7s
# [CV 1/3] END C=3, coef0=2, degree=3, kernel=poly;, score=0.950 total time=   4.6s
# [CV 2/3] END C=3, coef0=2, degree=3, kernel=poly;, score=0.957 total time=   5.1s
# [CV 3/3] END C=3, coef0=2, degree=3, kernel=poly;, score=0.951 total time=   4.5s
# [CV 1/3] END C=3, coef0=2, degree=5, kernel=poly;, score=0.954 total time=   4.6s
# [CV 2/3] END C=3, coef0=2, degree=5, kernel=poly;, score=0.960 total time=   5.0s
# [CV 3/3] END C=3, coef0=2, degree=5, kernel=poly;, score=0.953 total time=   4.6s
# [CV 1/3] END C=10.0, coef0=0, degree=3, kernel=poly;, score=0.949 total time=   4.7s
# [CV 2/3] END C=10.0, coef0=0, degree=3, kernel=poly;, score=0.958 total time=   4.8s
# [CV 3/3] END C=10.0, coef0=0, degree=3, kernel=poly;, score=0.954 total time=   4.6s
# [CV 1/3] END C=10.0, coef0=0, degree=5, kernel=poly;, score=0.907 total time=   5.8s
# [CV 2/3] END C=10.0, coef0=0, degree=5, kernel=poly;, score=0.923 total time=   6.4s
# [CV 3/3] END C=10.0, coef0=0, degree=5, kernel=poly;, score=0.912 total time=   5.8s
# [CV 1/3] END C=10.0, coef0=1, degree=3, kernel=poly;, score=0.953 total time=   4.3s
# [CV 2/3] END C=10.0, coef0=1, degree=3, kernel=poly;, score=0.959 total time=   4.7s
# [CV 3/3] END C=10.0, coef0=1, degree=3, kernel=poly;, score=0.953 total time=   4.6s
# [CV 1/3] END C=10.0, coef0=1, degree=5, kernel=poly;, score=0.954 total time=   4.8s
# [CV 2/3] END C=10.0, coef0=1, degree=5, kernel=poly;, score=0.959 total time=   4.8s
# [CV 3/3] END C=10.0, coef0=1, degree=5, kernel=poly;, score=0.953 total time=   4.7s
# [CV 1/3] END C=10.0, coef0=2, degree=3, kernel=poly;, score=0.950 total time=   4.6s
# [CV 2/3] END C=10.0, coef0=2, degree=3, kernel=poly;, score=0.957 total time=   4.6s
# [CV 3/3] END C=10.0, coef0=2, degree=3, kernel=poly;, score=0.951 total time=   4.3s
# [CV 1/3] END C=10.0, coef0=2, degree=5, kernel=poly;, score=0.954 total time=   4.5s
# [CV 2/3] END C=10.0, coef0=2, degree=5, kernel=poly;, score=0.960 total time=   4.7s
# [CV 3/3] END C=10.0, coef0=2, degree=5, kernel=poly;, score=0.953 total time=   4.5s
# GridSearchCV(cv=3, estimator=SVC(),
#              param_grid=[{'C': [1, 2, 3, 10.0], 'coef0': [0, 1, 2],
#                           'degree': [3, 5], 'kernel': ['poly']}],
#              verbose=3)

# %%
# lets see the best hyperparameters and score
print(grid_search_poly.best_params_)
print(grid_search_poly.best_score_)
# Out:
# {'C': 1, 'coef0': 2, 'degree': 5, 'kernel': 'poly'}
# 0.9556001490970933

# %%
# lets run a polynomial kernel with default values

svm_clf_poly = SVC(kernel="poly")
svm_clf_poly.fit(X_train_subset, y_train_subset)
y_pred = svm_clf_poly.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9522

# %%
# now with the best values for degree, C and coef0
# {'C': 1, 'coef0': 2, 'degree': 5, 'kernel': 'poly'}

svm_clf_poly_tuned = SVC(kernel="poly", degree=5, C=1, coef0=2)
svm_clf_poly_tuned.fit(X_train_subset, y_train_subset)
y_pred = svm_clf_poly_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9599

# %%
# now rbf with the best values for C and gamma
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}

svm_clf_rbf_tuned = SVC(kernel="rbf", C=10, gamma="scale")
svm_clf_rbf_tuned.fit(X_train_subset, y_train_subset)
y_pred = svm_clf_rbf_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9676

# %%
# also compute the f1 score of the tuned and stock models and precicion recall and computanional complexity
from sklearn.metrics import f1_score, precision_score, recall_score, classification_report

for model in [svm_clf_stock, svm_clf_poly_tuned, svm_clf_rbf_tuned]:
    print(model)
    print(classification_report(y_test, model.predict(X_test)))
# Out:
# SVC()
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       986
#            1       0.99      1.00      0.99      1125
#            2       0.99      0.98      0.99       999
#            3       0.99      0.98      0.99      1020
#            4       0.99      0.98      0.98       975
#            5       0.99      0.99      0.99       902
#            6       0.99      1.00      0.99       982
#            7       0.99      0.98      0.99      1042
#            8       0.99      0.99      0.99       975
#            9       0.98      0.98      0.98       994
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000
#
# SVC(C=1, coef0=2, degree=5, kernel='poly')
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       986
#            1       0.98      0.99      0.98      1125
#            2       0.96      0.95      0.96       999
#            3       0.95      0.94      0.94      1020
#            4       0.96      0.96      0.96       975
#            5       0.95      0.94      0.95       902
#            6       0.96      0.98      0.97       982
#            7       0.97      0.97      0.97      1042
#            8       0.95      0.94      0.95       975
#            9       0.94      0.94      0.94       994
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000
#
# SVC(C=10)
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       986
#            1       0.98      0.99      0.99      1125
#            2       0.97      0.97      0.97       999
#            3       0.96      0.95      0.95      1020
#            4       0.96      0.97      0.97       975
#            5       0.96      0.96      0.96       902
#            6       0.98      0.98      0.98       982
#            7       0.97      0.97      0.97      1042
#            8       0.96      0.96      0.96       975
#            9       0.95      0.94      0.95       994
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000

# %%
# get accuracy score for stock model on the test set

svm_clf_stock.score(X_test, y_test)
# Out:
# 0.9878

# %%
# visualize the precision recall curve for the 4 models so stock, linear, poly and rbf
# in one plot

import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve

# Re-initialize the models with probability=True
svm_clf_stock = SVC(probability=True)
svm_clf_poly_tuned = SVC(kernel="poly", degree=5, C=1, coef0=2, probability=True)
svm_clf_rbf_tuned = SVC(kernel="rbf", C=10, gamma="scale", probability=True)

# Re-train the models
svm_clf_stock.fit(X_train_subset, y_train_subset)
svm_clf_poly_tuned.fit(X_train_subset, y_train_subset)
svm_clf_rbf_tuned.fit(X_train_subset, y_train_subset)
# Out:
# SVC(probability=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 18
#      16 for model in [svm_clf_stock, svm_clf_poly_tuned, svm_clf_rbf_tuned]:
#      17     print(model)
# ---> 18     precision, recall, thresholds = precision_recall_curve(y_test, model.predict_proba(X_test)[:, 1])
#      19     plt.plot(recall, precision, label=model)
#      20     plt.xlabel('Recall')
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:1002, in precision_recall_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate, probas_pred)
#     993     warnings.warn(
#     994         (
#     995             "probas_pred was deprecated in version 1.5 and will be removed in 1.7."
#    (...)
#     998         FutureWarning,
#     999     )
#    1000     y_score = probas_pred
# -> 1002 fps, tps, thresholds = _binary_clf_curve(
#    1003     y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#    1004 )
#    1006 if drop_intermediate and len(fps) > 2:
#    1007     # Drop thresholds corresponding to points where true positives (tps)
#    1008     # do not change from the previous or subsequent point. This will keep
#    1009     # only the first and last point for each tps value. All points
#    1010     # with the same tps value have the same recall and thus x coordinate.
#    1011     # They appear as a vertical line on the plot.
#    1012     optimal_idxs = np.where(
#    1013         np.concatenate(
#    1014             [[True], np.logical_or(np.diff(tps[:-1]), np.diff(tps[1:])), [True]]
#    1015         )
#    1016     )[0]
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:817, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     815 y_type = type_of_target(y_true, input_name="y_true")
#     816 if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
# --> 817     raise ValueError("{0} format is not supported".format(y_type))
#     819 check_consistent_length(y_true, y_score, sample_weight)
#     820 y_true = column_or_1d(y_true)
#
# ValueError: multiclass format is not supported

# %%
# try marcos params for poly kernel

svm_clf_poly_marco = SVC(kernel="poly", degree=7, C=45, coef0=2)
svm_clf_poly_marco.fit(X_train, y_train)
y_pred = svm_clf_poly_marco.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.997

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.997
